# %%
import Modulos.swc_to_image as swc
import matplotlib.pyplot as plt
import numpy as np

img = swc.swc_to_image("kimimaro_out/1.swc", (1104, 1376))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-85f9e3101cc5> in <module>
#       3 import numpy as np
#       4
# ----> 5 img = swc.swc_to_image("kimimaro_out/1.swc", (1104, 1376))
#
# ~/Desktop/IC/Codigos/Modulos/swc_to_image.py in swc_to_image(filename, img_shape)
#      46
#      47     graph = swc_to_graph(filename)
# ---> 48     img = create_image(graph, img_shape)
#      49
#      50     return img
#
# ~/Desktop/IC/Codigos/Modulos/swc_to_image.py in create_image(graph, img_shape)
#      38         pos2 = graph.nodes[node2]['pos']
#      39         coords = draw.line_nd(pos1, pos2, endpoint=True)
# ---> 40         img[coords] = 255
#      41
#      42     return img
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
plt.figure(figsize=[15,15])
plt.imshow(np.max(img, axis=0), 'gray')
plt.show()
