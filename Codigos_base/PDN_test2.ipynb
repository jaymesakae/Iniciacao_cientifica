# %%
# Modulo para ler arquivos .pdn
# disponivel em: https://github.com/addisonElliott/pypdn
import pypdn

# Modulos auxiliares usados
from Modulos.modulos_auxiliares import *

# %%
def plot_graph_new(x, y, label, method):
    plt.figure(figsize = (15, 4))
    for i in range(len(label)):
        plt.subplot(1, 3, 1)
        plt.title('IOU values ' + method.upper())
        plt.plot(x, y[0][i], label=f'{label[i]}')
        plt.xlabel('Noise treatment')
        plt.ylabel("IOU values")
        plt.legend(fontsize = 'x-small', title = 'noise_aplication', title_fontsize = 'x-small')
        
        plt.subplot(1, 3, 2)
        plt.title('True Positive rate values ' + method.upper())
        plt.plot(x, y[1][i], label=f'{label[i]}')
        plt.xlabel('Noise treatment')
        plt.ylabel("Sensibility values")
        plt.legend(fontsize = 'x-small', title = 'noise_aplication', title_fontsize = 'x-small')
        
        plt.subplot(1, 3, 3)
        plt.title('Precision values ' + method.upper())
        plt.plot(x, y[2][i], label=f'{label[i]}')
        plt.xlabel('Noise treatment')
        plt.ylabel("Precision values")
        plt.legend(fontsize = 'x-small', title = 'noise_aplication', title_fontsize = 'x-small')
    return

# %% [markdown]
# # Importando a amostra

# %%
# nome = '3783.pdn'
# nome = '6769.pdn'
#nome = '9234.pdn'
# nome = '10394.pdn'
# nome = '12795.pdn'
nome = '17924.pdn'
nome = "../Amostras/Bach1/" + nome

img = pypdn.read(nome)

#print(img)

# %% [markdown]
# ## Imagem original da amostra

# %%
# dividir as camadas da imagem
img_original = img.layers[0].image

#print(img_original.shape)
#plt.imshow(img_original)

# %% [markdown]
# ## Segmentação binaria

# %%
segmentation = img.layers[1].image
#print(segmentation.shape)
segmentation = transform_nonbinary(segmentation[:,:,0])
#print(im.Image(segmentation))

# Aumentando o tamanho da imagem para o algoritmo manter segmento da imagem

segmentation = np.pad(segmentation, ((10,10), (10,10)), constant_values = True)

#plt.imshow(segmentation)

# %% [markdown]
# ## Importando o esqueleto feito a mão

# %%
skeleton = img.layers[3].image
#print(im.Image(skeleton))


skeleton = skeleton[:,:,2]

skeleton = transform_nonbinary(skeleton)
#print(im.Image(skeleton))

#print(skeleton)
#plt.imshow(skeleton)

# %% [markdown]
# ## Metricas comparativas dos esqueletos

# %% [markdown]
# # Adicionando ruido

# %%
noise_aplication = [0., 0.05, 0.1, 0.15, 0.2, 0.25]
noise_treatment = [0, 1, 2, 3, 4, 5, 6]

method = ['palagyi', 'zhang', 'lee', 'medial_axis']
data = {}

for metodo in method:
    data[metodo] = compare_skeleton(skeleton, segmentation, noise_aplication, noise_treatment, metodo)
#print(data)
# Out:
# tp precision:  3513 tp sensibility:  3526
# fp precision:  323 fn sensibility:  303
#
# tp precision:  3265 tp sensibility:  3477
# fp precision:  235 fn sensibility:  352
#
# tp precision:  3261 tp sensibility:  3472
# fp precision:  223 fn sensibility:  357
#
# tp precision:  3246 tp sensibility:  3461
# fp precision:  196 fn sensibility:  368
#
# tp precision:  3227 tp sensibility:  3442
# fp precision:  181 fn sensibility:  387
#
# tp precision:  3177 tp sensibility:  3388
# fp precision:  167 fn sensibility:  441
#
# tp precision:  3118 tp sensibility:  3327
# fp precision:  154 fn sensibility:  502
#
# tp precision:  3082 tp sensibility:  3289
# fp precision:  148 fn sensibility:  540
#
#
# ******** NOISE: 0.0 , METHOD: palagyi ********
# iou:  0.8489928838499577 sensibility 0.9208670671193523
# precision: 0.9157977059436914
#
#
# tp precision:  3529 tp sensibility:  3525
# fp precision:  433 fn sensibility:  304
#
# tp precision:  3265 tp sensibility:  3479
# fp precision:  312 fn sensibility:  350
#
# tp precision:  3256 tp sensibility:  3469
# fp precision:  291 fn sensibility:  360
#
# tp precision:  3240 tp sensibility:  3453
# fp precision:  246 fn sensibility:  376
#
# tp precision:  3213 tp sensibility:  3422
# fp precision:  214 fn sensibility:  407
#
# tp precision:  3184 tp sensibility:  3388
# fp precision:  199 fn sensibility:  441
#
# tp precision:  3127 tp sensibility:  3330
# fp precision:  187 fn sensibility:  499
#
# tp precision:  3097 tp sensibility:  3297
# fp precision:  170 fn sensibility:  532
#
#
# ******** NOISE: 0.05 , METHOD: palagyi ********
# iou:  0.8271575984990619 sensibility 0.9206059023243667
# precision: 0.8907117617364967
#
#
# tp precision:  3525 tp sensibility:  3498
# fp precision:  589 fn sensibility:  331
#
# tp precision:  3232 tp sensibility:  3458
# fp precision:  430 fn sensibility:  371
#
# tp precision:  3228 tp sensibility:  3451
# fp precision:  412 fn sensibility:  378
#
# tp precision:  3206 tp sensibility:  3428
# fp precision:  355 fn sensibility:  401
#
# tp precision:  3187 tp sensibility:  3407
# fp precision:  303 fn sensibility:  422
#
# tp precision:  3146 tp sensibility:  3362
# fp precision:  278 fn sensibility:  467
#
# tp precision:  3116 tp sensibility:  3329
# fp precision:  258 fn sensibility:  500
#
# tp precision:  3056 tp sensibility:  3268
# fp precision:  242 fn sensibility:  561
#
#
# ******** NOISE: 0.1 , METHOD: palagyi ********
# iou:  0.7923953514611305 sensibility 0.9135544528597545
# precision: 0.8568303354399611
#
#
# tp precision:  3514 tp sensibility:  3485
# fp precision:  903 fn sensibility:  344
#
# tp precision:  3196 tp sensibility:  3437
# fp precision:  663 fn sensibility:  392
#
# tp precision:  3186 tp sensibility:  3426
# fp precision:  637 fn sensibility:  403
#
# tp precision:  3151 tp sensibility:  3395
# fp precision:  534 fn sensibility:  434
#
# tp precision:  3145 tp sensibility:  3386
# fp precision:  422 fn sensibility:  443
#
# tp precision:  3129 tp sensibility:  3368
# fp precision:  365 fn sensibility:  461
#
# tp precision:  3058 tp sensibility:  3288
# fp precision:  332 fn sensibility:  541
#
# tp precision:  3037 tp sensibility:  3265
# fp precision:  320 fn sensibility:  564
#
#
# ******** NOISE: 0.15 , METHOD: palagyi ********
# iou:  0.7372801011271464 sensibility 0.9101593105249413
# precision: 0.7955625990491284
#
#
# tp precision:  3491 tp sensibility:  3446
# fp precision:  1192 fn sensibility:  383
#
# tp precision:  3156 tp sensibility:  3408
# fp precision:  874 fn sensibility:  421
#
# tp precision:  3145 tp sensibility:  3397
# fp precision:  842 fn sensibility:  432
#
# tp precision:  3132 tp sensibility:  3376
# fp precision:  752 fn sensibility:  453
#
# tp precision:  3102 tp sensibility:  3334
# fp precision:  596 fn sensibility:  495
#
# tp precision:  3067 tp sensibility:  3294
# fp precision:  517 fn sensibility:  535
#
# tp precision:  3039 tp sensibility:  3264
# fp precision:  419 fn sensibility:  565
#
# tp precision:  2990 tp sensibility:  3215
# fp precision:  381 fn sensibility:  614
#
#
# ******** NOISE: 0.2 , METHOD: palagyi ********
# iou:  0.6877168632893824 sensibility 0.8999738835205014
# precision: 0.745462310484732
#
#
# tp precision:  3513 tp sensibility:  3422
# fp precision:  1588 fn sensibility:  407
#
# tp precision:  3148 tp sensibility:  3378
# fp precision:  1206 fn sensibility:  451
#
# tp precision:  3139 tp sensibility:  3371
# fp precision:  1168 fn sensibility:  458
#
# tp precision:  3126 tp sensibility:  3346
# fp precision:  1045 fn sensibility:  483
#
# tp precision:  3075 tp sensibility:  3302
# fp precision:  876 fn sensibility:  527
#
# tp precision:  3034 tp sensibility:  3258
# fp precision:  744 fn sensibility:  571
#
# tp precision:  2986 tp sensibility:  3209
# fp precision:  621 fn sensibility:  620
#
# tp precision:  2956 tp sensibility:  3188
# fp precision:  579 fn sensibility:  641
#
#
# ******** NOISE: 0.25 , METHOD: palagyi ********
# iou:  0.6347826086956522 sensibility 0.8937059284408462
# precision: 0.6886884924524603
#
#
# tp precision:  3635 tp sensibility:  3539
# fp precision:  515 fn sensibility:  290
#
# tp precision:  3347 tp sensibility:  3494
# fp precision:  339 fn sensibility:  335
#
# tp precision:  3313 tp sensibility:  3479
# fp precision:  290 fn sensibility:  350
#
# tp precision:  3267 tp sensibility:  3449
# fp precision:  237 fn sensibility:  380
#
# tp precision:  3226 tp sensibility:  3412
# fp precision:  200 fn sensibility:  417
#
# tp precision:  3154 tp sensibility:  3349
# fp precision:  177 fn sensibility:  480
#
# tp precision:  3040 tp sensibility:  3254
# fp precision:  165 fn sensibility:  575
#
# tp precision:  3013 tp sensibility:  3229
# fp precision:  159 fn sensibility:  600
#
#
# ******** NOISE: 0.0 , METHOD: zhang ********
# iou:  0.816712204007286 sensibility 0.9242622094541656
# precision: 0.8759036144578313
#
#
# tp precision:  3644 tp sensibility:  3514
# fp precision:  658 fn sensibility:  315
#
# tp precision:  3344 tp sensibility:  3470
# fp precision:  454 fn sensibility:  359
#
# tp precision:  3275 tp sensibility:  3434
# fp precision:  386 fn sensibility:  395
#
# tp precision:  3222 tp sensibility:  3398
# fp precision:  300 fn sensibility:  431
#
# tp precision:  3181 tp sensibility:  3366
# fp precision:  244 fn sensibility:  463
#
# tp precision:  3104 tp sensibility:  3292
# fp precision:  220 fn sensibility:  537
#
# tp precision:  3008 tp sensibility:  3212
# fp precision:  206 fn sensibility:  617
#
# tp precision:  2967 tp sensibility:  3172
# fp precision:  197 fn sensibility:  657
#
#
# ******** NOISE: 0.05 , METHOD: zhang ********
# iou:  0.7862478031634447 sensibility 0.9177330895795247
# precision: 0.8470478847047884
#
#
# tp precision:  3707 tp sensibility:  3541
# fp precision:  975 fn sensibility:  288
#
# tp precision:  3380 tp sensibility:  3501
# fp precision:  675 fn sensibility:  328
#
# tp precision:  3307 tp sensibility:  3465
# fp precision:  589 fn sensibility:  364
#
# tp precision:  3225 tp sensibility:  3421
# fp precision:  467 fn sensibility:  408
#
# tp precision:  3154 tp sensibility:  3366
# fp precision:  364 fn sensibility:  463
#
# tp precision:  3071 tp sensibility:  3299
# fp precision:  311 fn sensibility:  530
#
# tp precision:  3002 tp sensibility:  3236
# fp precision:  297 fn sensibility:  593
#
# tp precision:  2947 tp sensibility:  3189
# fp precision:  288 fn sensibility:  640
#
#
# ******** NOISE: 0.1 , METHOD: zhang ********
# iou:  0.7415592387968079 sensibility 0.9247845390441368
# precision: 0.7917556599743699
#
#
# tp precision:  3657 tp sensibility:  3473
# fp precision:  1243 fn sensibility:  356
#
# tp precision:  3277 tp sensibility:  3414
# fp precision:  849 fn sensibility:  415
#
# tp precision:  3193 tp sensibility:  3368
# fp precision:  733 fn sensibility:  461
#
# tp precision:  3103 tp sensibility:  3320
# fp precision:  590 fn sensibility:  509
#
# tp precision:  3030 tp sensibility:  3264
# fp precision:  458 fn sensibility:  565
#
# tp precision:  2961 tp sensibility:  3207
# fp precision:  400 fn sensibility:  622
#
# tp precision:  2903 tp sensibility:  3159
# fp precision:  371 fn sensibility:  670
#
# tp precision:  2856 tp sensibility:  3121
# fp precision:  356 fn sensibility:  708
#
#
# ******** NOISE: 0.15 , METHOD: zhang ********
# iou:  0.6903563129357088 sensibility 0.9070253329851136
# precision: 0.7463265306122449
#
#
# tp precision:  3679 tp sensibility:  3463
# fp precision:  1597 fn sensibility:  366
# tp precision:  3299 tp sensibility:  3410
# fp precision:  1132 fn sensibility:  419
#
# tp precision:  3217 tp sensibility:  3359
# fp precision:  1012 fn sensibility:  470
#
# tp precision:  3127 tp sensibility:  3315
# fp precision:  828 fn sensibility:  514
#
# tp precision:  3001 tp sensibility:  3225
# fp precision:  655 fn sensibility:  604
#
# tp precision:  2910 tp sensibility:  3159
# fp precision:  568 fn sensibility:  670
#
# tp precision:  2880 tp sensibility:  3138
# fp precision:  516 fn sensibility:  691
#
# tp precision:  2790 tp sensibility:  3068
# fp precision:  436 fn sensibility:  761
#
#
# ******** NOISE: 0.2 , METHOD: zhang ********
# iou:  0.6452837007589447 sensibility 0.9044136850352572
# precision: 0.6973085670962851
#
#
# tp precision:  3771 tp sensibility:  3488
# fp precision:  2123 fn sensibility:  341
#
# tp precision:  3376 tp sensibility:  3434
# fp precision:  1580 fn sensibility:  395
#
# tp precision:  3291 tp sensibility:  3385
# fp precision:  1445 fn sensibility:  444
#
# tp precision:  3184 tp sensibility:  3323
# fp precision:  1249 fn sensibility:  506
#
# tp precision:  3101 tp sensibility:  3266
# fp precision:  1033 fn sensibility:  563
#
# tp precision:  3018 tp sensibility:  3218
# fp precision:  860 fn sensibility:  611
#
# tp precision:  2970 tp sensibility:  3177
# fp precision:  776 fn sensibility:  652
#
# tp precision:  2907 tp sensibility:  3124
# fp precision:  702 fn sensibility:  705
#
#
# ******** NOISE: 0.25 , METHOD: zhang ********
# iou:  0.5956346927053418 sensibility 0.9109428049098981
# precision: 0.6398031896844248
#
#
# tp precision:  3511 tp sensibility:  3549
# fp precision:  201 fn sensibility:  280
#
# tp precision:  3280 tp sensibility:  3487
# fp precision:  153 fn sensibility:  342
#
# tp precision:  3271 tp sensibility:  3480
# fp precision:  150 fn sensibility:  349
#
# tp precision:  3259 tp sensibility:  3467
# fp precision:  137 fn sensibility:  362
#
# tp precision:  3234 tp sensibility:  3439
# fp precision:  131 fn sensibility:  390
#
# tp precision:  3199 tp sensibility:  3400
# fp precision:  127 fn sensibility:  429
#
# tp precision:  3157 tp sensibility:  3358
# fp precision:  119 fn sensibility:  471
#
# tp precision:  3100 tp sensibility:  3296
# fp precision:  116 fn sensibility:  533
#
#
# ******** NOISE: 0.0 , METHOD: lee ********
# iou:  0.8800797806033408 sensibility 0.926873857404022
# precision: 0.9458512931034483
#
#
# tp precision:  3499 tp sensibility:  3531
# fp precision:  331 fn sensibility:  298
#
# tp precision:  3260 tp sensibility:  3469
# fp precision:  249 fn sensibility:  360
#
# tp precision:  3249 tp sensibility:  3463
# fp precision:  244 fn sensibility:  366
#
# tp precision:  3245 tp sensibility:  3456
# fp precision:  221 fn sensibility:  373
#
# tp precision:  3214 tp sensibility:  3420
# fp precision:  184 fn sensibility:  409
#
# tp precision:  3168 tp sensibility:  3372
# fp precision:  167 fn sensibility:  457
#
# tp precision:  3141 tp sensibility:  3343
# fp precision:  156 fn sensibility:  486
#
# tp precision:  3081 tp sensibility:  3279
# fp precision:  148 fn sensibility:  550
#
#
# ******** NOISE: 0.05 , METHOD: lee ********
# iou:  0.8482142857142857 sensibility 0.9221728910942805
# precision: 0.9135770234986945
#
#
# tp precision:  3476 tp sensibility:  3487
# fp precision:  509 fn sensibility:  342
#
# tp precision:  3224 tp sensibility:  3428
# fp precision:  384 fn sensibility:  401
#
# tp precision:  3217 tp sensibility:  3418
# fp precision:  379 fn sensibility:  411
#
# tp precision:  3200 tp sensibility:  3403
# fp precision:  354 fn sensibility:  426
#
# tp precision:  3181 tp sensibility:  3383
# fp precision:  283 fn sensibility:  446
#
# tp precision:  3144 tp sensibility:  3345
# fp precision:  242 fn sensibility:  484
#
# tp precision:  3095 tp sensibility:  3299
# fp precision:  228 fn sensibility:  530
#
# tp precision:  3036 tp sensibility:  3237
# fp precision:  215 fn sensibility:  592
#
#
# ******** NOISE: 0.1 , METHOD: lee ********
# iou:  0.8035776110790537 sensibility 0.9106816401149125
# precision: 0.8722710163111669
#
#
# tp precision:  3467 tp sensibility:  3474
# fp precision:  763 fn sensibility:  355
#
# tp precision:  3180 tp sensibility:  3417
# fp precision:  582 fn sensibility:  412
#
# tp precision:  3173 tp sensibility:  3410
# fp precision:  553 fn sensibility:  419
#
# tp precision:  3158 tp sensibility:  3383
# fp precision:  503 fn sensibility:  446
#
# tp precision:  3148 tp sensibility:  3369
# fp precision:  411 fn sensibility:  460
#
# tp precision:  3116 tp sensibility:  3333
# fp precision:  354 fn sensibility:  496
#
# tp precision:  3046 tp sensibility:  3259
# fp precision:  327 fn sensibility:  570
#
# tp precision:  3003 tp sensibility:  3209
# fp precision:  302 fn sensibility:  620
#
#
# ******** NOISE: 0.15 , METHOD: lee ********
# iou:  0.7563473902146671 sensibility 0.9072864977800993
# precision: 0.8196217494089835
#
#
# tp precision:  3504 tp sensibility:  3454
# fp precision:  1130 fn sensibility:  375
#
# tp precision:  3166 tp sensibility:  3398
# fp precision:  855 fn sensibility:  431
#
# tp precision:  3158 tp sensibility:  3389
# fp precision:  824 fn sensibility:  440
#
# tp precision:  3140 tp sensibility:  3358
# fp precision:  718 fn sensibility:  471
#
# tp precision:  3100 tp sensibility:  3318
# fp precision:  583 fn sensibility:  511
#
# tp precision:  3046 tp sensibility:  3263
# fp precision:  514 fn sensibility:  566
#
# tp precision:  3031 tp sensibility:  3241
# fp precision:  452 fn sensibility:  588
#
# tp precision:  2980 tp sensibility:  3182
# fp precision:  394 fn sensibility:  647
#
#
# ******** NOISE: 0.2 , METHOD: lee ********
# iou:  0.6980337078651685 sensibility 0.9020632018803866
# precision: 0.7561501942166595
#
#
# tp precision:  3494 tp sensibility:  3454
# fp precision:  1526 fn sensibility:  375
#
# tp precision:  3115 tp sensibility:  3404
# fp precision:  1160 fn sensibility:  425
#
# tp precision:  3105 tp sensibility:  3391
# fp precision:  1106 fn sensibility:  438
#
# tp precision:  3068 tp sensibility:  3358
# fp precision:  1007 fn sensibility:  471
#
# tp precision:  3044 tp sensibility:  3328
# fp precision:  856 fn sensibility:  501
#
# tp precision:  2981 tp sensibility:  3270
# fp precision:  714 fn sensibility:  559
#
# tp precision:  2960 tp sensibility:  3250
# fp precision:  612 fn sensibility:  579
#
# tp precision:  2927 tp sensibility:  3217
# fp precision:  552 fn sensibility:  612
#
#
# ******** NOISE: 0.25 , METHOD: lee ********
# iou:  0.6463255813953488 sensibility 0.9020632018803866
# precision: 0.69601593625498
#
#
# tp precision:  3720 tp sensibility:  3591
# fp precision:  1308 fn sensibility:  238
#
# tp precision:  3223 tp sensibility:  3513
# fp precision:  761 fn sensibility:  316
#
# tp precision:  3190 tp sensibility:  3492
# fp precision:  603 fn sensibility:  337
#
# tp precision:  3137 tp sensibility:  3461
# fp precision:  401 fn sensibility:  368
#
# tp precision:  3096 tp sensibility:  3432
# fp precision:  266 fn sensibility:  397
#
# tp precision:  3067 tp sensibility:  3405
# fp precision:  214 fn sensibility:  424
#
# tp precision:  3035 tp sensibility:  3375
# fp precision:  176 fn sensibility:  454
#
# tp precision:  2933 tp sensibility:  3276
# fp precision:  169 fn sensibility:  553
#
#
# ******** NOISE: 0.0 , METHOD: medial_axis ********
# iou:  0.7027780447947707 sensibility 0.9378427787934186
# precision: 0.7398568019093079
#
#
# tp precision:  3730 tp sensibility:  3591
# fp precision:  1674 fn sensibility:  238
#
# tp precision:  3200 tp sensibility:  3512
# fp precision:  985 fn sensibility:  317
#
# tp precision:  3163 tp sensibility:  3486
# fp precision:  774 fn sensibility:  343
#
# tp precision:  3109 tp sensibility:  3438
# fp precision:  513 fn sensibility:  391
#
# tp precision:  3058 tp sensibility:  3422
# fp precision:  332 fn sensibility:  407
#
# tp precision:  3017 tp sensibility:  3386
# fp precision:  271 fn sensibility:  443
#
# tp precision:  2980 tp sensibility:  3347
# fp precision:  232 fn sensibility:  482
#
# tp precision:  2905 tp sensibility:  3280
# fp precision:  213 fn sensibility:  549
#
#
# ******** NOISE: 0.05 , METHOD: medial_axis ********
# iou:  0.6568864961866308 sensibility 0.9378427787934186
# precision: 0.6902294596595114
#
#
# tp precision:  3772 tp sensibility:  3569
# fp precision:  2083 fn sensibility:  260
#
# tp precision:  3212 tp sensibility:  3505
# fp precision:  1246 fn sensibility:  324
#
# tp precision:  3154 tp sensibility:  3465
# fp precision:  997 fn sensibility:  364
#
# tp precision:  3052 tp sensibility:  3405
# fp precision:  655 fn sensibility:  424
# tp precision:  2978 tp sensibility:  3364
# fp precision:  450 fn sensibility:  465
#
# tp precision:  2929 tp sensibility:  3319
# fp precision:  331 fn sensibility:  510
#
# tp precision:  2893 tp sensibility:  3289
# fp precision:  276 fn sensibility:  540
#
# tp precision:  2820 tp sensibility:  3219
# fp precision:  253 fn sensibility:  610
#
#
# ******** NOISE: 0.1 , METHOD: medial_axis ********
# iou:  0.6103766525318034 sensibility 0.9320971533037347
# precision: 0.6442356959863365
#
#
# tp precision:  3813 tp sensibility:  3572
# fp precision:  2464 fn sensibility:  257
#
# tp precision:  3241 tp sensibility:  3486
# fp precision:  1534 fn sensibility:  343
#
# tp precision:  3163 tp sensibility:  3445
# fp precision:  1301 fn sensibility:  384
#
# tp precision:  3053 tp sensibility:  3379
# fp precision:  882 fn sensibility:  450
#
# tp precision:  2966 tp sensibility:  3332
# fp precision:  618 fn sensibility:  497
#
# tp precision:  2918 tp sensibility:  3302
# fp precision:  487 fn sensibility:  527
#
# tp precision:  2866 tp sensibility:  3258
# fp precision:  422 fn sensibility:  571
#
# tp precision:  2759 tp sensibility:  3162
# fp precision:  379 fn sensibility:  667
#
#
# ******** NOISE: 0.15 , METHOD: medial_axis ********
# iou:  0.5757386762298277 sensibility 0.9328806476886916
# precision: 0.6074557909829537
#
#
# tp precision:  3827 tp sensibility:  3544
# fp precision:  2934 fn sensibility:  285
#
# tp precision:  3256 tp sensibility:  3480
# fp precision:  1879 fn sensibility:  349
#
# tp precision:  3197 tp sensibility:  3440
# fp precision:  1616 fn sensibility:  389
#
# tp precision:  3030 tp sensibility:  3345
# fp precision:  1225 fn sensibility:  484
#
# tp precision:  2931 tp sensibility:  3265
# fp precision:  852 fn sensibility:  564
#
# tp precision:  2829 tp sensibility:  3187
# fp precision:  710 fn sensibility:  642
#
# tp precision:  2809 tp sensibility:  3174
# fp precision:  615 fn sensibility:  655
#
# tp precision:  2735 tp sensibility:  3101
# fp precision:  524 fn sensibility:  728
#
#
# ******** NOISE: 0.2 , METHOD: medial_axis ********
# iou:  0.5337823158809472 sensibility 0.9255680334290938
# precision: 0.566040526549327
#
#
# tp precision:  3829 tp sensibility:  3536
# fp precision:  3407 fn sensibility:  293
#
# tp precision:  3241 tp sensibility:  3461
# fp precision:  2225 fn sensibility:  368
#
# tp precision:  3171 tp sensibility:  3420
# fp precision:  1936 fn sensibility:  409
#
# tp precision:  3047 tp sensibility:  3351
# fp precision:  1491 fn sensibility:  478
#
# tp precision:  2919 tp sensibility:  3272
# fp precision:  1146 fn sensibility:  557
#
# tp precision:  2853 tp sensibility:  3226
# fp precision:  915 fn sensibility:  603
#
# tp precision:  2780 tp sensibility:  3169
# fp precision:  753 fn sensibility:  660
#
# tp precision:  2748 tp sensibility:  3143
# fp precision:  681 fn sensibility:  686
#
#
# ******** NOISE: 0.25 , METHOD: medial_axis ********
# iou:  0.49881476464612257 sensibility 0.9234787150692086
# precision: 0.529159756771697

# %%
# [0.8423540534152683, 0.8144920889704196], [0.9334029772786628, 0.9297466701488639], [0.8961169944528492, 0.8677766895200784]

# %%
iou_palagyi, tpr_palagyi, ppv_palagyi = data['palagyi'][0]
iou_graph_palagyi, tpr_graph_palagyi, ppv_graph_palagyi = data['palagyi'][1]

iou_zhang, tpr_zhang, ppv_zhang = data['zhang'][0]
iou_graph_zhang, tpr_graph_zhang, ppv_graph_zhang = data['zhang'][1]

iou_lee, tpr_lee, ppv_lee = data['lee'][0]
iou_graph_lee, tpr_graph_lee, ppv_graph_lee = data['lee'][1]

iou_MA, tpr_MA, ppv_MA = data['medial_axis'][0]
iou_graph_MA, tpr_graph_MA, ppv_graph_MA = data['medial_axis'][1]

#print(data['medial_axis'][1][0] == iou_graph_MA)

# %% [markdown]
# ## plotando os graficos de qualidade

# %%
plt.figure(figsize = [10,10])
plt.subplot(3,1,1)
plot_graph((iou_zhang, iou_MA, iou_palagyi, iou_lee), ('Skimage (Zhang)', 'Medial Axis', 'Palagyi and Kuba', 'Skimage (Lee)'), 'iou values', 'iou operation', noise_aplication, ('r', 'g', 'b', 'k'))

plt.figure(figsize = [10,10])
plt.subplot(3,1,2)
plot_graph((tpr_zhang, tpr_MA, tpr_palagyi, tpr_lee), ('Skimage (Zhang)', 'Medial Axis', 'Palagyi and Kuba', 'Skimage (Lee)'), 'tpr values', 'sensibility (tpr) operation', noise_aplication, ('r', 'g', 'b', 'k'))

plt.figure(figsize = [10,10])
plt.subplot(3,1,3)
plot_graph((ppv_zhang, ppv_MA, ppv_palagyi, ppv_lee), ('Skimage (Zhang)', 'Medial Axis', 'Palagyi and Kuba', 'Skimage (Lee)'), 'ppv values', 'precision (ppv) operation', noise_aplication, ('r', 'g', 'b', 'k'))

# %%
for metodo in method:
    plot_graph_new(noise_treatment, data[metodo][1], noise_aplication, metodo)

# %%
for i in ppv_graph_lee:
    print(i, '\n')
# Out:
# [0.9554325662685698, 0.9561531715872552, 0.959658421672556, 0.9610698365527489, 0.9618159951894167, 0.9636752136752137, 0.9639303482587065]
#
# [0.9290396124251924, 0.9301460062983109, 0.9362377380265435, 0.9458505002942907, 0.9499250374812593, 0.9526842584167425, 0.9541653762774853]
#
# [0.893569844789357, 0.8946051167964405, 0.9003939223410242, 0.9183025404157044, 0.928529238038984, 0.9313873006319591, 0.9338665026145802]
#
# [0.8452950558213717, 0.8515834675254965, 0.8626058453974323, 0.8845181230682776, 0.8979827089337176, 0.903053661428995, 0.9086232980332829]
#
# [0.787366326784382, 0.7930688096433953, 0.813893208916537, 0.8417051316861255, 0.8556179775280899, 0.87022681596325, 0.8832246591582691]
#
# [0.7286549707602339, 0.7373545476133935, 0.7528834355828221, 0.7805128205128206, 0.8067658998646821, 0.8286674132138858, 0.8413337165852256]
